# %%
import urllib
import urllib2
import cookielib
import re
from bs4 import BeautifulSoup

cookie = cookielib.CookieJar()
handler=urllib2.HTTPCookieProcessor(cookie)
opener = urllib2.build_opener(handler)

# url = 'https://www.medanswering.com/login.taf?_function=check'
# user_name = 'operr126'
# pwd = 'Hawkins1@'
# referer = 'https://www.medanswering.com/login.taf'
# user_agent = 'Mozilla/4.0 (compatible; MSIE 5.5; Windows NT)'
# values = { 'User_Name' : user_name, 'Password' : pwd, 'eulaAgree' : 1}
# headers = { 'User-Agent' : user_agent , 'Referer' : referer}
# data = urllib.urlencode(values)
# result = opener.open(url, data)
# status = result.getcode()
#
# url_TPCL = 'https://www.medanswering.com/admintransproviders.taf?_function=listselfproviders&'
# url_NYC = 'https://www.medanswering.com/admintransproviders.taf?_function=detail&Provider_ID=31462'
#
# result = opener.open(url_NYC)
# content = result.read()

content = '<tr valign="top" bgcolor="#F7F3FF"> <td align="center" style="font-family: Arial; font-size: 11;"> 12/10/18 </td> <td> please update on PA number, thanks. </td> <td> Completed </td> <td> Updated Med Provider Info. </td> <td> </td> <td align="center"> 12/19/2018 08:08 AM </td> <td align="center"> <a href="/admintrips.taf?_function=detail&Trip_Auth_ID=68455411">684554110</a> </td> <td> NYC </td> <td align="center"> 11/15/2018 </td> </tr> <tr valign="top" bgcolor="#F7F3FF"> <td align="center" style="font-family: Arial; font-size: 11;"> 12/10/18 </td> <td> please update on PA number, thanks. </td> <td> Completed </td> <td> Updated Med Provider Info. </td> <td>'
url = 'https://www.medanswering.com/login.taf?_function=check'
user_name = "operr126"
pwd = "Hawkins2@"
values = { 'User_Name' : user_name, 'Password' : pwd, 'eulaAgree' : 1}
data = urllib.urlencode(values)
opener.open(url, data)
# url_correction="https://www.medanswering.com/admincorrectionrequests.taf?_function=transproviderlist&"
# result = opener.open(url_correction)
url = 'https://www.medanswering.com/admincorrectionrequests.taf?_function=transproviderlist&_start=001'
result = opener.open(url)
content = result.read()

soup = BeautifulSoup(content, 'lxml')
# table_corr = soup.find('table', attrs={'border': "0", 'cellspacing': "1", 'cellpadding': "3"})

# %%
corrs = soup.find_all('tr', attrs={'valign': "top", 'bgcolor': "#F7F3FF"})

for corr in corrs:
    attrs = corr.find_all('td')
    print len(attrs)
    for i in range(len(attrs)):
        print(attrs[i].get_text().strip())
# pattern = re.compile('<tr.*?>.*?<td.*?>(.*?)</td>.*?<td.*?>(.*?)</td>.*?<td.*?>(.*?)</td>.*?<td.*?>(.*?)</td>.*?<td.*?>(.*?)</td>.*?<td.*?>(.*?)</td>.*?<td.*?<a.*?>(.*?)</a>.*?</td>.*?<td.*?>(.*?)</td>.*?<td.*?>(.*?)</td>.*?</tr>', re.S)
# items = re.findall(pattern, corrs.get_text())
# for item in items:
#     print(item[0].strip())
# Out:
# 9
# 03/06/19
# Please remove code A0170TU, these trips took place only in kings County. And please generate PA#, updated with Epaces timely. Thanks. This correction should NOT Overdue.
# Overdue
#
#
#
# 755434860
# NYC
# 01/30/2019
# 9
# 03/05/19
# This canceled trip has been completed by our driver, please re-activate trips, in order for us to attest. thank you.
# Completed
# Vendor accidentally cancelled trip
#
# 03/06/2019 04:14 PM
# 731500270
# NYC
# 02/23/2019
# 9
# 03/05/19
# This canceled trip has been completed by our driver, please re-activate trips, in order for us to attest. thank you.
# Completed
# Trip did take place
#
# 03/05/2019 05:55 PM
# 766247360
# NYC
# 02/22/2019
# 9
# 03/05/19
# This canceled trip has been completed by our driver, please re-activate trips, in order for us to attest. thank you.
# Needed
#
#
#
# 731696820
# NYC
# 02/21/2019
# 9
# 03/05/19
# The original Invoice#731499790 is a correction, this attestation should NOT overdue, please change trips' status to Eligible attest. Thanks
# Overdue
#
#
#
# 774327370
# NYC
# 02/01/2019
# 9
# 03/05/19
# Please either correct Invoice#731499830, or give NEW Invoice# and please update the correction to Epaces timely. Thanks.
# Overdue
#
#
#
# 731499830
# NYC
# 02/02/2019
# 9
# 03/05/19
# Please either correct Invoice#731500010, or give NEW Invoice# and please update the correction to Epaces timely. Thanks.
# Needed
#
#
#
# 731500010
# NYC
# 02/09/2019
# 9
# 03/05/19
# Please either correct Invoice#731500160, or give NEW Invoice# and please update the correction to Epaces timely. Thanks.
# Needed
#
#
#
# 731500160
# NYC
# 02/16/2019
# 9
# 03/05/19
# The original Invoice#730511110 is a correction, this attestation should NOT overdue, please change trips' status to Eligible attest. Thanks
# Overdue
#
#
#
# 774331160
# NYC
# 02/01/2019
# 9
# 03/05/19
# The original Invoice#730511120 is a correction, this attestation should NOT overdue, please change trips' status to Eligible attest. Thanks
# Overdue
#
#
#
# 774335170
# NYC
# 02/02/2019
# 9
# 03/05/19
# The original Invoice#730551750 is a correction, this attestation should NOT overdue, please change trips' status to Eligible attest. Thanks
# Overdue
#
#
#
# 774366190
# NYC
# 02/01/2019
# 9
# 03/05/19
# The original Invoice#730551790 is a correction, this attestation should NOT overdue, please change trips' status to Eligible attest. Thanks
# Overdue
#
#
#
# 774369240
# NYC
# 02/02/2019
# 9
# 03/05/19
# The original Invoice#730574030 is a correction, this attestation should NOT overdue, please change trips' status to Eligible attest. Thanks
# Overdue
#
#
#
# 774376590
# NYC
# 02/02/2019
# 9
# 03/04/19
# Invoice#755747650 only completed A&D Leg, B&C Leg should be Invoice#758505400. Please combine these TWO Invoice into ONE and update with Epaces timely. Thank you.
# Overdue
#
#
#
# 755747650
# NYC
# 01/31/2019
# 9
# 03/02/19
# THIS PATIENT WAS TRANSPORTED TO AND FROM THE PROGRAM, PLEASE VERIFY. THANK YOU !
# Completed
# Correction not needed
# Enrollee was ineligible for d.o.s.
# 03/05/2019 03:19 PM
# 731812790
# NYC
# 03/02/2019
# 9
# 02/28/19
# S0215 RATE 3.21 CHANGE INTO 3.41
# Overdue
#
#
#
# 744973810
# NYC
# 12/14/2018
# 9
# 02/28/19
# Please change trip's attestation status to Eligible.This correction should not be Overdue. Please update S0215 TN units with Epaces. Thank you!
# Overdue
#
#
#
# 644633910
# NYC
# 10/01/2018
# 9
# 02/28/19
# Please change trip's attestation status to Eligible.This correction should not be Overdue.
# Please update S0215 TN units with Epaces. Thank you!
# Overdue
#
#
#
# 668959570
# NYC
# 10/12/2018
# 9
# 02/28/19
# A Leg S0215 RATE should be updated with Epaces as 2019 Price=$3.41/unit.
# Completed
# Incorrect Rate
#
# 03/02/2019 12:57 PM
# 731941600
# NYC
# 02/06/2019
# 9
# Secondary/Anc Serv. added
#
# 03/04/2019 03:09 PM
# 730552080
# NYC
# 02/16/2019
# 9
# 02/28/19
# Each Leg exceed 8 miles,S0215 should apply.
# Completed
# Secondary/Anc Serv. added
#
# 03/04/2019 03:09 PM
# 730552070
# NYC
# 02/15/2019
# 9
# 02/28/19
# Each Leg exceed 8 miles,S0215 should apply.
# Completed
# Secondary/Anc Serv. added
#
# 03/04/2019 03:09 PM
# 730552040
# NYC
# 02/14/2019
# 9
# 02/28/19
# Each Leg exceed 8 miles,S0215 should apply.
# Completed
# Secondary/Anc Serv. added
#
# 03/04/2019 03:09 PM
# 730552010
# NYC
# 02/13/2019
# 9
# 02/28/19
# Each Leg exceed 8 miles,S0215 should apply.
# Completed
# Secondary/Anc Serv. added
#
# 03/04/2019 03:09 PM
# 730551980
# NYC
# 02/12/2019
# 9
# 02/28/19
# Each Leg exceed 8 miles,S0215 should apply.
# Completed
# Secondary/Anc Serv. added
#
# 03/04/2019 03:09 PM
# 730551960
# NYC
# 02/11/2019
# 9
# 02/28/19
# Each Leg exceed 8 miles,S0215 should apply.
# Completed
# Secondary/Anc Serv. added
#
# 03/04/2019 03:09 PM
# 730551930
# NYC
# 02/09/2019
# 9
# 02/28/19
# Each Leg exceed 8 miles,S0215 should apply.
# Completed
# Secondary/Anc Serv. added
#
# 03/04/2019 03:09 PM
# 730551900
# NYC
# 02/08/2019
# 9
# 02/28/19
# Each Leg exceed 8 miles,S0215 should apply.
# Completed
# Secondary/Anc Serv. added
#
# 03/04/2019 03:09 PM
# 730551870
# NYC
# 02/07/2019
# 9
# 02/28/19
# Each Leg exceed 8 miles,S0215 should apply.
# Completed
# Secondary/Anc Serv. added
#
# 03/04/2019 03:09 PM
# 730551850
# NYC
# 02/06/2019
# 9
# 02/28/19
# Each Leg exceed 8 miles,S0215 should apply.
# Completed
# Secondary/Anc Serv. added
#
# 03/04/2019 03:09 PM
# 730551820
# NYC
# 02/05/2019
# 9
# 02/28/19
# Each Leg exceed 8 miles,S0215 should apply.
# Completed
# Secondary/Anc Serv. added
#
# 03/04/2019 03:09 PM
# 730551800
# NYC
# 02/04/2019
# 9
# 02/28/19
# Each Leg exceed 8 miles,S0215 should apply.
# Completed
# Secondary/Anc Serv. added
#
# 03/04/2019 03:09 PM
# 730551790
# NYC
# 02/02/2019
# 9
# 02/28/19
# Each Leg exceed 8 miles,S0215 should apply.
# Completed
# Secondary/Anc Serv. added
#
# 03/04/2019 03:09 PM
# 730551750
# NYC
# 02/01/2019
# 9
# 02/28/19
# Each Leg exceed 8 miles,S0215 should apply.
# Completed
# Secondary/Anc Serv. added
#
# 03/06/2019 02:48 PM
# 731474900
# NYC
# 02/06/2019
# 9
# 02/27/19
# This correction should NOT overdue,B leg S0215 had not update into Epaces.
# Overdue
#
#
#
# 708833550
# NYC
# 11/30/2018
# 9
# 02/27/19
# This correction should NOT overdue,B leg S0215 had not update into Epaces.
# Overdue
#
#
#
# 707728770
# NYC
# 11/27/2018
# 9
# 02/27/19
# This correction should NOT overdue, trips NOT allow to reattest and B leg S0215 had not update into Epaces.
# Overdue
#
#
#
# 707510980
# NYC
# 11/29/2018
# 9
# 02/27/19
# This correction should NOT overdue, trips NOT allow to reattest and B leg S0215 had not update into Epaces.
# Overdue
#
#
#
# 707717390
# NYC
# 11/27/2018
# 9
# 02/26/19
# Each Leg exceed 5 miles, A0100 TN should apply.
# Completed
# Incorrect Transport Mode
#
# 03